// %% [markdown]
// <h1 style="color:DodgerBlue">Создание экземпляров классов (объектов) и взаимодействие объектов между собой</h1>

// %% [markdown]
// ### Создание экземпляров классов (объектов)
//
// В C#, экземпляр класса создается с помощью оператора `new`, который выделяет память для нового объекта и вызывает конструктор класса для инициализации этого объекта. Конструктор — это специальный метод в классе, который имеет то же имя, что и класс, и используется для установки начального состояния объекта.
//
// #### Пример создания экземпляров классов Vehicle и Car
//
// ```csharp
// Vehicle myVehicle = new Vehicle();
// Car myCar = new Car();
// ```
//
// В этом примере создаются два объекта: один для класса `Vehicle` и другой для класса `Car`. Конструкторы этих классов будут автоматически вызваны при создании объектов.
//
// ### Взаимодействие объектов между Собой
//
// Взаимодействие объектов между собой означает, что один объект может вызывать методы другого объекта или обращаться к его свойствам (если они доступны). Это позволяет объектам обмениваться информацией и координировать свои действия.
//
// #### Пример взаимодействия объектов
//
// ```csharp
// myVehicle.Color = "Red";
// myVehicle.Speed = 60;
//
// myCar.Color = "Blue";
// myCar.FuelLevel = 100;
// myCar.Refuel(50); // Увеличиваем уровень топлива на 50
// ```
//
// В этом примере мы устанавливаем свойства `Color` и `Speed` для объекта `myVehicle`, а также свойства `Color` и `FuelLevel` для объекта `myCar`. Затем мы вызываем метод `Refuel` у объекта `myCar`, чтобы увеличить его уровень топлива.
//
// ### Закрепление правил использования модификаторов доступа
//
// Модификаторы доступа определяют уровень доступности членов класса из других частей кода. Важно правильно использовать модификаторы доступа для обеспечения безопасности и инкапсуляции данных.
//
// #### Примеры модификаторов доступа в классах Vehicle и Car
//
// ```csharp
// public class Vehicle
// {
//     public string Color { get; set; } // public свойство
//     private int speed; // private поле
//
//     protected void SetSpeed(int value) // protected метод
//     {
//         speed = value;
//     }
// }
//
// public class Car : Vehicle
// {
//     private int fuelLevel; // private поле
//
//     public void Refuel(int amount) // public метод
//     {
//         fuelLevel += amount;
//     }
//
//     protected void CheckSpeedLimit() // protected метод
//     {
//         if (speed > 120)
//         {
//             Console.WriteLine("Превышен скоростной режим!");
//         }
//     }
// }
// ```
//
// В этом примере:
// - Свойство `Color` в классе `Vehicle` объявлено как `public`, что позволяет доступ к нему из любого места в коде.
// - Поле `speed` в классе `Vehicle` объявлено как `private`, что ограничивает доступ к нему только внутри класса `Vehicle`.
// - Метод `SetSpeed` в классе `Vehicle` объявлен как `protected`, что позволяет доступ к нему из класса `Vehicle` и его производных классов.
// - Поле `fuelLevel` в классе `Car` объявлено как `private`, ограничивая доступ к нему только внутри класса `Car`.
// - Методы `Refuel` и `CheckSpeedLimit` в классе `Car` демонстрируют использование модификаторов доступа для контроля над тем, как объекты могут взаимодействовать друг с другом.
//
// ### Заключение
//
// Создание экземпляров классов и взаимодействие между объектами являются ключевыми аспектами объектно-ориентированного программирования в C#. Правильное использование модификаторов доступа обеспечивает безопасность данных и инкапсуляцию, позволяя разработчикам создавать более надежные и управляемые программы.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Car и Vehicle ниже в блоке:</h4>
//
// ----

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (2-3 например Dog, Cat и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также статические и обычными атрибуты и метода класса с реализацией взаимодействия между объектами.

// %%
using System;

public class Animal
{
    private string _name;
    private int _age;
    private string _species;
    private int _satiety;

    public string Name
    {
        get { return _name; }
        set { _name = value; }
    }

    public int Age
    {
        get { return _age; }
        set
        {
            if (value >= 0)
                _age = value;
        }
    }

    public string Species
    {
        get { return _species; }
        set { _species = value; }
    }

    public int Satiety
    {
        get { return _satiety; }
        protected set
        {
            if (value < 0) _satiety = 0;
            else if (value > 100) _satiety = 100;
            else _satiety = value;
        }
    }

    public static int TotalAnimals { get; private set; } = 0;

    public Animal()
    {
        _name = "Безымянное";
        _age = 0;
        _species = "Неизвестно";
        _satiety = 50;
        TotalAnimals++;
    }

    public Animal(string name, int age, string species)
    {
        _name = name;
        _age = age;
        _species = species;
        _satiety = 50;
        TotalAnimals++;
    }

    public virtual void MakeSound()
    {
        Console.WriteLine($"{Name} издаёт звук.");
    }

    public void Eat(string food, int amount)
    {
        Satiety += amount;
        Console.WriteLine($"{Name} ест {food}. Сытость: {Satiety}");
    }

    public void DecreaseSatiety(int amount)
    {
        Satiety -= amount;
    }

    public static void DisplayTotalAnimals()
    {
        Console.WriteLine($"Общее количество животных: {TotalAnimals}");
    }

    public override string ToString()
    {
        return $"Animal: Name={Name}, Age={Age}, Species={Species}, Satiety={Satiety}";
    }
}

public class Dog : Animal
{
    private string _breed;
    private int _energyLevel;

    public string Breed
    {
        get { return _breed; }
        set { _breed = value; }
    }

    public int EnergyLevel
    {
        get { return _energyLevel; }
        private set
        {
            if (value < 0) _energyLevel = 0;
            else if (value > 100) _energyLevel = 100;
            else _energyLevel = value;
        }
    }

    public Dog() : base()
    {
        _breed = "Дворняга";
        _energyLevel = 100;
    }

    public Dog(string name, int age, string breed) : base(name, age, "Собака")
    {
        _breed = breed;
        _energyLevel = 100;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} ({Breed}) говорит: Гав-гав!");
    }

    public void Play(int minutes)
    {
        EnergyLevel -= minutes;
        Satiety -= minutes / 2;
        Console.WriteLine($"{Name} играет {minutes} мин. Энергия: {EnergyLevel}, Сытость: {Satiety}");
    }

    public void Rest()
    {
        EnergyLevel = 100;
        Console.WriteLine($"{Name} отдохнул. Энергия: {EnergyLevel}");
    }

    public void FeedFromOwner(Cat catOwner)
    {
        Console.WriteLine($"{Name} получает еду от {catOwner.Name}.");
        Eat("корм", 30);
        catOwner.DecreaseSatiety(10);
        Console.WriteLine($"{catOwner.Name} поделился едой. Сытость {catOwner.Name}: {catOwner.Satiety}");
    }
}

public class Cat : Animal
{
    private bool _isIndoor;
    private int _livesLeft;

    public bool IsIndoor
    {
        get { return _isIndoor; }
        set { _isIndoor = value; }
    }

    public int LivesLeft
    {
        get { return _livesLeft; }
        private set
        {
            if (value < 0) _livesLeft = 0;
            else if (value > 9) _livesLeft = 9;
            else _livesLeft = value;
        }
    }

    public Cat() : base()
    {
        _isIndoor = true;
        _livesLeft = 9;
    }

    public Cat(string name, int age, bool isIndoor) : base(name, age, "Кошка")
    {
        _isIndoor = isIndoor;
        _livesLeft = 9;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} говорит: Мяу!");
    }

    public void Hunt()
    {
        if (_livesLeft > 0)
        {
            LivesLeft--;
            Satiety += 20;
            Console.WriteLine($"{Name} охотится. Осталось жизней: {LivesLeft}, Сытость: {Satiety}");
        }
        else
        {
            Console.WriteLine($"{Name} больше не может охотиться.");
        }
    }

    public void ShareFoodWith(Dog dog)
    {
        Console.WriteLine($"{Name} делится едой с {dog.Name}.");
        DecreaseSatiety(15);
        Console.WriteLine($"{Name} отдал еду. Сытость {Name}: {Satiety}");
    }
}

public class Bird : Animal
{
    private double _wingSpan;
    private bool _canFly;

    public double WingSpan
    {
        get { return _wingSpan; }
        set
        {
            if (value > 0)
                _wingSpan = value;
        }
    }

    public bool CanFly
    {
        get { return _canFly; }
        set { _canFly = value; }
    }

    public Bird() : base()
    {
        _wingSpan = 20.0;
        _canFly = true;
    }

    public Bird(string name, int age, double wingSpan, bool canFly) : base(name, age, "Птица")
    {
        _wingSpan = wingSpan;
        _canFly = canFly;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} поёт: Чик-чирик!");
    }

    public void Fly()
    {
        if (CanFly)
        {
            Satiety -= 10;
            Console.WriteLine($"{Name} летает с размахом крыльев {WingSpan} см. Сытость: {Satiety}");
        }
        else
        {
            Console.WriteLine($"{Name} не умеет летать.");
        }
    }

    public void BringFoodTo(Animal animal)
    {
        Console.WriteLine($"{Name} приносит еду для {animal.Name}.");
        animal.Eat("зерно", 20);
    }
}

Animal genericAnimal = new Animal("Зверь", 3, "Неизвестный");
Dog dog = new Dog("Рекс", 4, "Лабрадор");
Cat cat = new Cat("Мурка", 2, true);
Bird bird = new Bird("Кеша", 1, 25.5, true);

Console.WriteLine("\nЗвуки");
genericAnimal.MakeSound();
dog.MakeSound();
cat.MakeSound();
bird.MakeSound();

Console.WriteLine("\nДействия объектов");
dog.Play(30);
dog.Rest();
cat.Hunt();
bird.Fly();

Console.WriteLine("\nКормление");
genericAnimal.Eat("мясо", 20);
dog.Eat("корм", 25);
cat.Eat("рыбу", 30);
bird.Eat("зерно", 15);

Console.WriteLine("\nВзаимодействие объектов");
dog.FeedFromOwner(cat);
cat.ShareFoodWith(dog);
bird.BringFoodTo(dog);

Console.WriteLine("\nСтатистика");
Animal.DisplayTotalAnimals();
// Out:
// Звуки
// Зверь издаёт звук.
// Рекс (Лабрадор) говорит: Гав-гав!
// Мурка говорит: Мяу!
// Кеша поёт: Чик-чирик!
//
// Действия объектов
// Рекс играет 30 мин. Энергия: 70, Сытость: 35
// Рекс отдохнул. Энергия: 100
// Мурка охотится. Осталось жизней: 8, Сытость: 70
// Кеша летает с размахом крыльев 25,5 см. Сытость: 40
//
// Кормление
// Зверь ест мясо. Сытость: 70
// Рекс ест корм. Сытость: 60
// Мурка ест рыбу. Сытость: 100
// Кеша ест зерно. Сытость: 55
//
// Взаимодействие объектов
// Рекс получает еду от Мурка.
// Рекс ест корм. Сытость: 90
// Мурка поделился едой. Сытость Мурка: 90
// Мурка делится едой с Рекс.
// Мурка отдал еду. Сытость Мурка: 75
// Кеша приносит еду для Рекс.
// Рекс ест зерно. Сытость: 100
//
// Статистика
// Общее количество животных: 4
